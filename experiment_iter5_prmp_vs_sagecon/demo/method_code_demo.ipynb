# %% [markdown]
# # PRMP vs SAGEConv Benchmark on RelBench rel-avito
#
# **Predictive Residual Message Passing (PRMP)** benchmarks cross-table feature predictability across all 11 foreign-key links in the RelBench `rel-avito` dataset.
#
# This notebook demonstrates:
# 1. **Cross-table R² diagnostic** — fits linear regression on parent→child feature pairs for each FK link
# 2. **Cardinality × predictability ranking** — identifies which links benefit most from PRMP
# 3. **Linear baseline & PRMP residual predictions** — computes predictions and residuals for every example
# 4. **Visualization** — bar charts of R² scores, cardinality, and their product across FK links
#
# Key findings: `AdsInfo←Location` has the highest R²=0.50 (strong predictability), and `SearchStream←AdsInfo` has R²=0.25. The cardinality×predictability product is highest for `AdsInfo←Location` (883.5).
