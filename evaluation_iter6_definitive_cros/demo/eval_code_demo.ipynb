# %% [markdown]
# # Definitive Cross-Dataset Meta-Analysis for PRMP
#
# This notebook demonstrates the comprehensive meta-analysis evaluation synthesizing 11 PRMP experiments across 5 iterations. It computes:
#
# - **DerSimonian-Laird random-effects meta-analysis** (Hedges' g effect sizes)
# - **Embedding-space regime theory validation** (Spearman correlation)
# - **Regression-vs-classification moderator analysis** (Q_between test)
# - **Mechanism decomposition** (7 components, predict-subtract contribution)
# - **6 publication-ready figures** (forest plots, scatter plots, bar charts)
